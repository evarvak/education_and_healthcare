# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
children = pd.read_sas('./data/nsch_2016e_topical.sas7bdat')

# %%
children.head()
# Out:
#   FIPSST         HHID FORMTYPE  TOTKIDS_R  HHLANGUAGE  SC_AGE_YEARS  SC_SEX  \
# 0  b'18'  b'16000030'    b'T1'        1.0         1.0           2.0     1.0
# 1  b'17'  b'16000032'    b'T2'        1.0         1.0           9.0     1.0
# 2  b'50'  b'16000050'    b'T2'        1.0         1.0          11.0     1.0
# 3  b'51'  b'16000051'    b'T2'        3.0         1.0          10.0     2.0
# 4  b'53'  b'16000090'    b'T3'        1.0         1.0          15.0     2.0
#
#    K2Q35A_1_YEARS  MOMAGE  K6Q41R_STILL  ...  BREASTFEDEND_WK_S  \
# 0             NaN    28.0           2.0  ...                NaN
# 1             6.0    40.0           NaN  ...                NaN
# 2             NaN    28.0           NaN  ...                NaN
# 3             NaN    37.0           NaN  ...                NaN
# 4             NaN    30.0           NaN  ...                NaN
#
#    BREASTFEDEND_MO_S  FRSTFORMULA_DAY_S  FRSTFORMULA_WK_S  FRSTFORMULA_MO_S  \
# ...

# %%
children.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50212 entries, 0 to 50211
# Columns: 432 entries, FIPSST to WEIGHT
# dtypes: float64(428), object(4)
# memory usage: 165.5+ MB

# %%
for col in children.columns:
    print(col)
# Out:
# FIPSST
# HHID
# FORMTYPE
# TOTKIDS_R
# HHLANGUAGE
# SC_AGE_YEARS
# SC_SEX
# K2Q35A_1_YEARS
# MOMAGE
# K6Q41R_STILL
# K6Q42R_NEVER
# K6Q43R_NEVER
# K6Q13A
# K6Q13B
# K6Q14A
# K6Q14B
# K4Q32X01
# K4Q32X02
# K4Q32X03
# K4Q32X04
# K4Q32X05
# DENTALSERV1
# DENTALSERV2
# DENTALSERV3
# DENTALSERV4
# DENTALSERV5
# DENTALSERV6
# DENTALSERV7
# K4Q28X01
# K4Q28X02
# K4Q28X03
# K4Q28X_EAR
# K4Q28X04
# K4Q28X05
# SESPLANYR
# SESPLANMO
# K4Q37
# SPCSERVMO
# LIVEUSA_YR
# LIVEUSA_MO
# K11Q43R
# A1_AGE
# A1_LIVEUSA
# A2_AGE
# A2_LIVEUSA
# HHCOUNT
# FAMCOUNT
# BREATHING
# SWALLOWING
# STOMACH
# PHYSICALPAIN
# HANDS
# COORDINATION
# TOOTHACHES
# GUMBLEED
# CAVITIES
# MEMORYCOND
# WALKSTAIRS
# DRESSING
# ERRANDALONE
# K2Q43B
# BLINDNESS
# ALLERGIES
# ALLERGIES_CURR
# ARTHRITIS
# ARTHRITIS_CURR
# K2Q40A
# K2Q40B
# BLOOD
# BLOOD_CURR
# K2Q46A
# K2Q46B
# K2Q61A
# K2Q61B
# CYSTFIB
# CYSTFIB_CURR
# K2Q41A
# K2Q41B
# DOWNSYN
# DOWNSYN_CURR
# K2Q42A
# K2Q42B
# GENETIC
# GENETIC_CURR
# HEART
# HEART_CURR
# ...

# %% [markdown]
# Here is a (non-exhaustive) list of some potentially useful variables present in the data.

# %%
geographical = children[['FIPSST', 
                         'CBSAFP_YN', 'METRO_YN', 'MPC_YN'
                        ]]
educational = children[[#'GRADES',
                       'K7Q02R_R', 'K7Q83_R'
                        ]]
healthcare = children[[ # 'AVAILABLE', 'APPOINTMENT', 'ISSUECOST', 'NOTELIG', 'NOTOPEN', 'TRANSPORTCC', 
                       'CURRCOV', 'HOWMUCH', 'INSTYPE', 'K3Q04_R', 'K12Q12',
                        'K3Q21B',
                        'K3Q20', 'K3Q22', 
                        'K3Q25',
                       'K4Q01', 'K4Q24_R', 
                       # 'K4Q26', 
                       'K4Q27', 'S4Q01']]

# %%
features = geographical.join(educational).join(healthcare)

# %%
features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50212 entries, 0 to 50211
# Data columns (total 19 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   FIPSST     50212 non-null  object
#  1   CBSAFP_YN  23623 non-null  float64
#  2   METRO_YN   33795 non-null  float64
#  3   MPC_YN     29493 non-null  float64
#  4   K7Q02R_R   34961 non-null  float64
#  5   K7Q83_R    34948 non-null  float64
#  6   CURRCOV    50024 non-null  float64
#  7   HOWMUCH    49474 non-null  float64
#  8   INSTYPE    50024 non-null  float64
#  9   K3Q04_R    50000 non-null  float64
#  10  K12Q12     40956 non-null  float64
#  11  K3Q21B     38906 non-null  float64
#  12  K3Q20      48125 non-null  float64
#  13  K3Q22      48035 non-null  float64
#  14  K3Q25      38963 non-null  float64
#  15  K4Q01      50032 non-null  float64
#  16  K4Q24_R    49772 non-null  float64
#  17  K4Q27      50036 non-null  float64
#  18  S4Q01      50134 non-null  float64
# ...

# %%
features.dropna().info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7618 entries, 18 to 50211
# Data columns (total 19 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   FIPSST     7618 non-null   object
#  1   CBSAFP_YN  7618 non-null   float64
#  2   METRO_YN   7618 non-null   float64
#  3   MPC_YN     7618 non-null   float64
#  4   K7Q02R_R   7618 non-null   float64
#  5   K7Q83_R    7618 non-null   float64
#  6   CURRCOV    7618 non-null   float64
#  7   HOWMUCH    7618 non-null   float64
#  8   INSTYPE    7618 non-null   float64
#  9   K3Q04_R    7618 non-null   float64
#  10  K12Q12     7618 non-null   float64
#  11  K3Q21B     7618 non-null   float64
#  12  K3Q20      7618 non-null   float64
#  13  K3Q22      7618 non-null   float64
#  14  K3Q25      7618 non-null   float64
#  15  K4Q01      7618 non-null   float64
#  16  K4Q24_R    7618 non-null   float64
#  17  K4Q27      7618 non-null   float64
#  18  S4Q01      7618 non-null   float64
# ...
