# %%
import pandas as pd

# %%
children = pd.read_sas('./nsch_2021e_topical.sas7bdat')

# %%
children.head()
# Out:
#   FIPSST STRATUM         HHID FORMTYPE  TOTKIDS_R  TENURE  HHLANGUAGE  \
# 0  b'48'    b'1'  b'21000002'    b'T1'        2.0     1.0         3.0
# 1  b'02'    b'1'  b'21000009'    b'T3'        1.0     2.0         1.0
# 2  b'40'    b'1'  b'21000017'    b'T2'        2.0     1.0         1.0
# 3  b'26'    b'1'  b'21000030'    b'T1'        1.0     1.0         1.0
# 4  b'22'    b'1'  b'21000031'    b'T1'        3.0     3.0         1.0
#
#    SC_AGE_YEARS  SC_SEX  K2Q35A_1_YEARS  ...  HIGRADE_TVIS  FPL_I1  FPL_I2  \
# 0           2.0     1.0             NaN  ...           4.0   400.0   400.0
# 1          12.0     1.0             NaN  ...           2.0   139.0   139.0
# 2           8.0     1.0             NaN  ...           4.0   395.0   395.0
# 3           2.0     2.0             NaN  ...           2.0   336.0   336.0
# 4           5.0     2.0             NaN  ...           2.0    96.0    96.0
#
#    FPL_I3  FPL_I4  FPL_I5  FPL_I6          FWC  HEIGHT  WEIGHT
# ...

# %%
children.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50892 entries, 0 to 50891
# Columns: 463 entries, FIPSST to WEIGHT
# dtypes: float64(459), object(4)
# memory usage: 179.8+ MB

# %%
for col in children.columns:
    print(col)
# Out:
# FIPSST
# STRATUM
# HHID
# FORMTYPE
# TOTKIDS_R
# TENURE
# HHLANGUAGE
# SC_AGE_YEARS
# SC_SEX
# K2Q35A_1_YEARS
# BIRTH_MO
# BIRTH_YR
# MOMAGE
# K6Q41R_STILL
# K6Q42R_NEVER
# K6Q43R_NEVER
# K6Q13A
# K6Q13B
# K6Q14A
# K6Q14B
# K4Q30_R_1
# K4Q30_R_2
# K4Q30_R_3
# DENTALSERV1
# DENTALSERV2
# DENTALSERV3
# DENTALSERV4
# DENTALSERV5
# DENTALSERV6
# DENTALSERV7
# K4Q28X01
# K4Q28X02
# K4Q28X03
# K4Q28X_EAR
# K4Q28X04
# K4Q28X05
# SESPLANYR
# SESPLANMO
# K4Q37
# SPCSERVMO
# LIVEUSA_YR
# LIVEUSA_MO
# K11Q43R
# A1_AGE
# A1_LIVEUSA
# A2_AGE
# A2_LIVEUSA
# HHCOUNT
# FAMCOUNT
# BREATHING
# SWALLOWING
# STOMACH
# PHYSICALPAIN
# HANDS
# COORDINATION
# TOOTHACHES
# GUMBLEED
# CAVITIES
# MEMORYCOND
# WALKSTAIRS
# DRESSING
# ERRANDALONE
# K2Q43B
# BLINDNESS
# ALLERGIES
# ALLERGIES_CURR
# ARTHRITIS
# ARTHRITIS_CURR
# K2Q40A
# K2Q40B
# K2Q61A
# K2Q61B
# K2Q41A
# K2Q41B
# K2Q42A
# K2Q42B
# HEART
# HEART_BORN
# HEART_CURR
# HEADACHE
# HEADACHE_CURR
# K2Q38A
# K2Q38B
# K2Q33A
# K2Q33B
# K2Q32A
# K2Q32B
# ...

# %%
df = pd.DataFrame()

df[['age','days_missed','covered','insured', 
        'hard_to_cover_basics', 'gov_assistance_plan', 'general_health', 
        'covered_past_12_months', 'insurance_meets_needs', 'insurance_costs_reasonable',
        'insurance_allows_to_see_provider', 'problem_paying_for_healthcare',
        'needed_healthcare_not_recieved', 'keep_insurance_as_adult', 'repeated_grade',
        'started_school', 'arrangements_closed_due_to_covid']] = children[['SC_AGE_YEARS',
                                                    'K7Q02R_R', 'CURRCOV', 'CURRINS', 'ACE1', 'K12Q12', 'K2Q01',
                                                    'K3Q04_R', 'K3Q20', 'K3Q21B', 'K3Q22', 'K3Q25', 'K4Q27', 
                                                    'KEEPINSADULT', 'REPEATED', 'STARTSCHOOL', 'COVIDARRANGE']]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50892 entries, 0 to 50891
# Data columns (total 17 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   age                               50892 non-null  float64
#  1   days_missed                       29822 non-null  float64
#  2   covered                           50672 non-null  float64
#  3   insured                           50672 non-null  float64
#  4   hard_to_cover_basics              49778 non-null  float64
#  5   gov_assistance_plan               48540 non-null  float64
#  6   general_health                    50779 non-null  float64
#  7   covered_past_12_months            50662 non-null  float64
#  8   insurance_meets_needs             48359 non-null  float64
#  9   insurance_costs_reasonable        35817 non-null  float64
#  10  insurance_allows_to_see_provider  48338 non-null  float64
# ...

# %%
df.head()
# Out:
#     age  days_missed  covered  insured  hard_to_cover_basics  \
# 0   2.0          NaN      1.0      1.0                   1.0
# 1  12.0          1.0      1.0      1.0                   3.0
# 2   8.0          2.0      1.0      1.0                   1.0
# 3   2.0          NaN      1.0      1.0                   2.0
# 4   5.0          NaN      1.0      1.0                   2.0
#
#    gov_assistance_plan  general_health  covered_past_12_months  \
# 0                  2.0             2.0                     1.0
# 1                  1.0             2.0                     1.0
# 2                  2.0             1.0                     1.0
# 3                  2.0             1.0                     1.0
# 4                  1.0             1.0                     1.0
#
#    insurance_meets_needs  insurance_costs_reasonable  \
# 0                    1.0                         2.0
# 1                    1.0                         NaN
# ...

# %%
import seaborn as sns

# %%
sns.histplot(df['days_missed'])
# Out:
# C:\Users\evarv\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='days_missed', ylabel='Count'>
